# %% [markdown]
# # Procedure

# %% [markdown]
# pandas and numpy are needed to work with dataframes

# %%
import pandas as pd
import numpy as np

# %%
def clean(df):
    return df

def clean_train(df):
    return clean(df), df[['SalePrice']]

def clean_test(df):
    return clean(df)

def feature_selection(X, y):
    return X.columns.tolist()

# %%
X, y = clean_train(pd.read_csv('data/train.csv'))
features = feature_selection(X, y)

from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor

params={}
#gcv=GridSearchCV(MLPRegressor(), params, n_jobs=-1, cv=5)
#gcv.fit(X[features], y)

# %% [markdown]
# # Commentary and Analysis

# %% [markdown]
# pyplot and seaborn are needed for visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
houses=pd.read_csv('data/train.csv')
y=houses['SalePrice']
X=pd.concat([houses.drop(columns=['SalePrice']), thouses])
categorical=np.setdiff1d(thouses.columns.values, thouses.describe().columns.values)
display(X.describe().T)
display(X[categorical].describe().T)

v=[]
for i in X.describe():
    v.append((i, X[i].nunique()))
print(*sorted(v, key=lambda i: i[1]))
# Out:
#                 count          mean          std     min     25%     50%  \
# Id             4379.0   1216.777803   806.819193     1.0   548.0  1095.0
# MSSubClass     4379.0     57.057547    42.440702    20.0    20.0    50.0
# LotFrontage    3634.0     69.551734    23.658891    21.0    59.0    68.0
# LotArea        4379.0  10284.378625  8642.241130  1300.0  7500.0  9464.0
# OverallQual    4379.0      6.092487     1.400870     1.0     5.0     6.0
# OverallCond    4379.0      5.568166     1.112905     1.0     5.0     5.0
# YearBuilt      4379.0   1971.297785    30.258509  1872.0  1954.0  1973.0
# YearRemodAdd   4379.0   1984.464946    20.811250  1950.0  1966.0  1993.0
# MasVnrArea     4348.0    102.696872   179.895021     0.0     0.0     0.0
# BsmtFinSF1     4378.0    442.162403   455.722473     0.0     0.0   374.5
# BsmtFinSF2     4378.0     48.570809   166.604819     0.0     0.0     0.0
# BsmtUnfSF      4378.0    562.929191   440.279892     0.0   221.0   470.0
# ...

# %%
houses.isnull().sum().apply(lambda i: i/2919)[houses.isnull().sum() != 0]

pd.concat([houses.drop(columns=['SalePrice']), thouses])[houses['MiscFeature']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-73fe2a678bac> in <module>
#       1 houses.isnull().sum().apply(lambda i: i/2919)[houses.isnull().sum() != 0]
#       2
# ----> 3 pd.concat([houses.drop(columns=['SalePrice']), thouses])[houses['MiscFeature']]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# ~/.local/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ...

# %%
# Out:
# 'BsmtFullBath[ 1.  0.  2.  3. nan]'
# 'BsmtHalfBath[ 0.  1.  2. nan]'
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.boxplot(y)
